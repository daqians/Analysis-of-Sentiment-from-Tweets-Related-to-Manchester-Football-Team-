# %%
text1= 'Ethics are built right into the ideals and objectives of the United Nations '

# %%
len(text1)
# Out:
# 76

# %%
text2= text1.split(" ")

# %%
text2
# Out:
# ['Ethics',
#  'are',
#  'built',
#  'right',
#  'into',
#  'the',
#  'ideals',
#  'and',
#  'objectives',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  '']

# %%
[w for w in text2 if len(w)>3]
# Out:
# ['Ethics',
#  'built',
#  'right',
#  'into',
#  'ideals',
#  'objectives',
#  'United',
#  'Nations']

# %%
[w for w in text2 if w.istitle()]
# Out:
# ['Ethics', 'United', 'Nations']

# %%
[w for w in text2 if w.endswith('s')]
# Out:
# ['Ethics', 'ideals', 'objectives', 'Nations']

# %%
text2[0].lower()
# Out:
# 'ethics'

# %%
raw_docs = ["Here are some very simple basic sentences.",
"They won't be very interesting, I'm afraid.",
"The point of these examples is to _learn how basic text cleaning works_ on *very simple* data."]

# %%
from nltk.tokenize import word_tokenize

# %%
tokenized_docs = [word_tokenize(doc) for doc in raw_docs]
print(tokenized_docs)
# Out:
# [['Here', 'are', 'some', 'very', 'simple', 'basic', 'sentences', '.'], ['They', 'wo', "n't", 'be', 'very', 'interesting', ',', 'I', "'m", 'afraid', '.'], ['The', 'point', 'of', 'these', 'examples', 'is', 'to', '_learn', 'how', 'basic', 'text', 'cleaning', 'works_', 'on', '*very', 'simple*', 'data', '.']]

# %%
import re
import string

regex = re.compile('[%s]' %re.escape(string.punctuation))

# %%
tokenized_docs_no_punctuation = []
for review in tokenized_docs:
    
    new_review = []
    for token in review: 
        new_token = regex.sub(u'', token)
        if not new_token == u'':
            new_review.append(new_token)
    tokenized_docs_no_punctuation.append(new_review)
    
print(tokenized_docs_no_punctuation)
# Out:
# [['Here', 'are', 'some', 'very', 'simple', 'basic', 'sentences'], ['They', 'wo', 'nt', 'be', 'very', 'interesting', 'I', 'm', 'afraid'], ['The', 'point', 'of', 'these', 'examples', 'is', 'to', 'learn', 'how', 'basic', 'text', 'cleaning', 'works', 'on', 'very', 'simple', 'data']]

# %%
from nltk.corpus import stopwords

tokenized_docs_no_stopwords = []
for doc in tokenized_docs_no_punctuation:
    new_term_vector = []
    for word in doc:
        if not word in stopwords.words('english'):
            new_term_vector.append(word)
    tokenized_docs_no_stopwords.append(new_term_vector)

print(tokenized_docs_no_stopwords)
# Out:
# [['Here', 'simple', 'basic', 'sentences'], ['They', 'wo', 'nt', 'interesting', 'I', 'afraid'], ['The', 'point', 'examples', 'learn', 'basic', 'text', 'cleaning', 'works', 'simple', 'data']]

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

porter = PorterStemmer()
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()

preprocessed_docs = []

for doc in tokenized_docs_no_stopwords:
    final_doc = []
    for word in doc:
        final_doc.append(porter.stem(word))
        #final_doc.append(snowball.stem(word))
        #final_doc.append(wordnet.lemmatize(word)) #note that lemmatize() can also takes part of speech as an argument!
    preprocessed_docs.append(final_doc)

print(preprocessed_docs)
# Out:
# [['here', 'simpl', 'basic', 'sentenc'], ['they', 'wo', 'nt', 'interest', 'I', 'afraid'], ['the', 'point', 'exampl', 'learn', 'basic', 'text', 'clean', 'work', 'simpl', 'data']]

# %%
import tweepy
import re

# %%
consumer_key = 'UKw2KLxameeRC2eUuMJVjdnaM'
consumer_secret = 'llDfpCz90ye74A3VL3bJdoASXMzNTTOgYyOfBWGUOnActXUYf7'
access_token = '927148475950751746-jPlH5nynmPNLzStdmlepsmDAmHKWVGB'
access_token_secret = '2R2P1ChKmmFsyqIMZwfOC461MPawFTB5SQQo2zCecljny'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# The most passes played in the #PL this season 👏
#
# @adrianjclarke takes a closer look at @fernandinho:… https://t.co/6vJL9aO4Lf
# “Wow. That, um, really went well” Prince said to me after his show with all the side-eye LOL.… https://t.co/7AweWtoRMj
# We’ll bring it back soon xx https://t.co/4nPgE6rKnn
# San Antonio, Charlotte and St. Louis are three of the long shots vying for an MLS team: https://t.co/g7Gsgr3F73
# Hahahahaha what on earth!!! https://t.co/hjBi2BGMcg
# Tomorrow night.
#
# #BeatThePatriots https://t.co/qxZai9AGm7
# We haven’t allowed a kick or punt return touchdown in 80 straight games.
#
# 5️⃣ Special Teams Stats to Know ➡️… https://t.co/CjP5Q3K0VK
# Real quick...this is not a parody account https://t.co/jKIX3p6Lqx
# Are you ready? #HereWeGo https://t.co/X3ACbzOvbe
# Here we go! Answering the @AskAnythingChat questions you guys sent for #MostRequestedLive &amp; @iHeartRadio here: https://t.co/daD1cY1FP2
# When you try to cut the line at the club. #TheVoice https://t.co/179Rg4jAVM
# RT @SteelersUnite: The fans are out here representing and enjoying the night with alumni Trai Essex! #SNUproud https://t.co/XiLfAYZeBE
# Why would Kim Jong-un insult me by calling me "old," when I would NEVER call him "short and fat?" Oh well, I try so… https://t.co/PmsWNkH4r4
# Does the Fake News Media remember when Crooked Hillary Clinton, as Secretary of State, was begging Russia to be our… https://t.co/0QnLU03c03
# Travis Kelce’s Fantasy Performance of the Week.
#
# Presented by @DraftKings https://t.co/vkV2UgMYTb
# Mexico will certainly entertain in Russia. https://t.co/EStmGxUHGX https://t.co/YJGASx7N3n
# I’m not as i’ll still be here in south america but i’ll be watching it on tellyyyy ✨ https://t.co/AUWk8fZllY
# RT @pcktdrgns: My Dad, at Soesterburg Air Force Base in 1973. Regardless of what people think of that war, I'm proud my Dad enlisted becaus…
# RT @bostonstrongg_: @30SECONDSTOMARS I love how in America we are free to be individuals and different and have the freedoms we do and I th…

# %%
query = "Manchester united"
language = "en"

results = api.search(q=query, lang=language)

# 遍历所拉取的全部微博
for tweet in results:
    print(tweet.user.screen_name,"Tweeted:",tweet.text)
# Out:
# zesty_manutd Tweeted: Winter spell crucial to United and Mourinho as City threaten to pull away https://t.co/jbmXZyOrYn https://t.co/MT45w5dMmL
# QuoteDailyGreys Tweeted: Manchester United Wags - https://t.co/Z6bq9uWWC6 https://t.co/vGRIjPjv7p
# BernardMudau Tweeted: RT @ManUtdReport_: We need players like this back at Manchester United. #mufc https://t.co/OyrVaokt4t
# THE_RED_DEVlLS Tweeted: RT @ChaskaBorek I have the good fortune to play for MANCHESTER UNITED. I do my best &amp; win everything there is to win. -Dimitar BERBATOV MUFC
# ManUtd_FootbalI Tweeted: RT @ChaskaBorek MANCHESTER UNITED made their first £100,000 signing in 1962 with the transfer of Denis Law from Torino for £110,000. -- MUFC
# Chaska_MUFC Tweeted: Im delighted to commit my future to MANCHESTER UNITED. -- JAVIER CHICHARITO HERNANDEZ MUFC ManUtd
# MUFC_REDS Tweeted: RT @ChaskaBorek MANCHESTER UNITED work on the long term, with young talent. -- ERIC CANTONA MUFC ManUtd
# TwitsFutbol Tweeted: Please RT!! #atleti #atletico #ATM  1-Ander Hererra (Manchester United) https://t.co/QiSwj1odcu
# ManUtd_rules Tweeted: RT @ChaskaBorek Joining MANCHESTER UNITED is a dream come true. The club is such an institution in Denmark. -- LINDEGAARD MUFC ALindegaard
# yukay_hn_vamps Tweeted: Remembrance: The players we lost in war https://t.co/TiBqVrk19H https://t.co/jiQoCey4On
# tswakomaifadi Tweeted: RT @SkySportsPL: Manchester United's Phil Jones suffered another potential injury setback after hobbling off in England's friendly against…
# JSocratesQuotes Tweeted: Top Manchester United Wags - https://t.co/3L5CuFR15Z https://t.co/HHwi6o03wH
# Us4UKShopping Tweeted: Manchester United Away Cup Shirt 2017-18 - Womens with Rooney 10 print #ManchesterUnited #ManUtd https://t.co/v4YpDZEP54
# MrMattyLee Tweeted: RT @ManUtdReport_: We need players like this back at Manchester United. #mufc https://t.co/OyrVaokt4t
# RennieHarry Tweeted: RT @ManUtdReport_: We need players like this back at Manchester United. #mufc https://t.co/OyrVaokt4t

# %%
len(results)
# Out:
# 15

# %%
api = tweepy.API(auth)  
  
  
highpoints = re.compile(u'[\uD800-\uDBFF][\uDC00-\uDFFF]')  
public_tweets = api.home_timeline()  
num = 0  
for tweet in public_tweets:  
    print(num) 
    num += 1  
    text_noem = highpoints.sub('--emoji--', tweet.text)  
    text_noem = text_noem.encode('utf8')
    print(text_noem)
# Out:
# 0
# b"RT @WWEUK: There's a NEW GM at @ManCity! @RealKurtAngle takes #TheBar to visit fellow champion @VincentKompany ahead of #RAW tonight at #WW\xe2\x80\xa6"
# 1
# b'\xf0\x9f\x92\xaa @WWECesaro, @WWESheamus &amp; @RealKurtAngle are on our Instagram Story at the Etihad Stadium taking penalties on the\xe2\x80\xa6 https://t.co/0zuZmlPGjF'
# 2
# b"RT @SteelersShop: First in, last out.  #MotivationMonday \n\nGet @_TJWatt's  tee \xf0\x9f\x91\x89 https://t.co/6TIw1cphQT https://t.co/CjQ3IWsfQn"
# 3
# b'Ibrahim Afellay gets off the #PL mark in style \xf0\x9f\x98\x8d\n\n@stokecity #GoalOfTheDay https://t.co/CtikMzeDHv'
# 4
# b'there\xe2\x80\x99s not enough loyalty out here.'
# 5
# b"\xe2\x98\x91 your calendars \xf0\x9f\x87\xba\xf0\x9f\x87\xb8 let's find an IDOL\xe2\x9d\x97@AmericanIdol will premiere Sunday, March 11 on ABC. #AmericanIdol https://t.co/adKVabe5EE"
# 6
# b"RT @stokecity: #SCFC players and staff at Clayton Wood and the bet365 Stadium hold a minute's silence in memory of former player Dionatan T\xe2\x80\xa6"
# 7
# b'My diet is not going wel. I ordered hot wings cupcakes and pizza yesterday. \xf0\x9f\xa4\xa6\xf0\x9f\x8f\xbc\xe2\x80\x8d\xe2\x99\x80\xef\xb8\x8f'
# 8
# b'RT @SteelersYouthFB: We want you to decide what game we cover Friday for our  #SteelersShowcase, vote here! https://t.co/inBTY371gi https:/\xe2\x80\xa6'
# 9
# b'Just bumped into @shadymeadows hitchiking to be an extra for the video as you were LG x https://t.co/zSAomOV71H'
# 10
# b"Michael Emenalo has resigned from his position as Chelsea's technical director. \n\nESPN sources:\xe2\x80\xa6 https://t.co/2hMVR0a4TH"
# 11
# b'Zlatan Ibrahimovic returned to former club Malmo last night and helped them celebrate a truly historic moment:\xe2\x80\xa6 https://t.co/do9dQBBVXV'
# 12
# b'RT @liam_twomey: Michael Emenalo has left Chelsea. Full @ESPNFC story shortly #cfc'
# 13
# b'for your monday morning... and mine. https://t.co/aRJIvT3DHZ https://t.co/u6LtGLmay5'
# 14
# b'Remembering Dudley Simpson, the veteran #DoctorWho composer who has died, aged 95 \xc2\xbb https://t.co/02UnBacsy5 https://t.co/lapLG23U5n'
# 15
# b'We have added WR Justin Thomas to our practice squad, and released OT Jake Rodgers from our practice squad.'
# 16
# b'As a committed Living Wage employer we are proud to support @LivingWageUK during #LivingWageWeek. \xf0\x9f\x91\x8d'
# 17
# b"Start Monday off by revisiting one of the wildest rallies in Flushing Meadows from the 90's...\n\n@Leander \xf0\x9f\xa4\x9d\xe2\x80\xa6 https://t.co/0LsAqedDUP"
# 18
# b"Back to the scene of the crime king tuts it's been too long as you were LG x"
# 19
# b"RT @Bundesliga_EN: \xf0\x9f\x94\x8e The mystery of @matshummels' holey Klassiker boots \xf0\x9f\xa4\x94 \n\nTurns out there is method in the madness \xf0\x9f\x91\x89 https://t.co/wgN2hhU\xe2\x80\xa6"

# %%
user = api.get_user('KingJames')

# %%
print(api.rate_limit_status()['resources']['search'])
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 0, 'reset': 1510426512}}

# %%
print(user.screen_name)
print(user.followers_count)
for friend in user.friends():
    print(friend.screen_name)
# Out:
# KingJames
# 39487942
# mconley11
# priyankachopra
# oliviawilde
# TheHerd
# ddlovato
# camrenbicondova
# jtimberlake
# rihanna
# timelesssports_
# GalGadot
# CassidyHubbarth
# alinabaraz
# bellachef19
# FLOTUS44
# BarackObama
# POTUS44
# JColeNC
# EzekielElliott
# isaaclarian
# LittleTikes

# %%
print('Location: ' + user.location)
# Out:
# Location: Manchester, England

# %%
#write with json
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

    
twitter_stream = Stream(api.auth, MyListener())
twitter_stream.filter(track=['Manchester city'],async=True)

# %%
import tweepy
import json
from dateutil import parser

WORDS = ['Old trafford','#Manchester United', '#ROMELU LUKAKU', '#JOSE MOURINHO', '#Man Utd', '#PAUL POGBA','#Manchester City','#VINCENT KOMPANY','#PEP GUARDIOLA','#Etihad']

# %%
class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 

    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        
        except Exception as e:
            print(e)

# %%
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
# Out:
# Tracking: ['Old trafford', '#Manchester United', '#ROMELU LUKAKU', '#JOSE MOURINHO', '#Man Utd', '#PAUL POGBA', '#Manchester City', '#VINCENT KOMPANY', '#PEP GUARDIOLA', '#Etihad']
# You are now connected to the streaming API.
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-e438444b5b9a> in <module>()
#       2 streamer = tweepy.Stream(auth=auth, listener=listener)
#       3 print("Tracking: " + str(WORDS))
# ----> 4 streamer.filter(track=WORDS)
#
# /anaconda/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /anaconda/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /anaconda/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /anaconda/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /anaconda/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /anaconda/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /anaconda/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     287                 raise
#     288         except OpenSSL.SSL.WantReadError:
# --> 289             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290             if not rd:
#     291                 raise timeout('The read operation timed out')
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/selectors.py in select(self, timeout)
#     511
#     512             kevent_list = _syscall_wrapper(self._kqueue.control, True,
# --> 513                                            None, max_events, timeout)
#     514
#     515             for kevent in kevent_list:
#
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:

# %%
MU=[]
MC=[]

# %%
#write with search
from time import sleep

i=0
for tweet in tweepy.Cursor(api.search,q='Manchester United').items():
    #i=i+1
    #if i%1000==0: time.sleep(9000);
    try:
        MU.append((tweet.user.screen_name,tweet.text,tweet.geo,tweet.user.location,tweet.user.followers_count,tweet.user.friends_count,tweet.created_at))
    except tweepy.TweepError as e:
        print(e.reason)

    except StopIteration:
        break
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-23-513fd2a3c9bc> in <module>()
#       3
#       4 i=0
# ----> 5 for tweet in tweepy.Cursor(api.search,q='Manchester United').items():
#       6     #i=i+1
#       7     #if i%1000==0: time.sleep(9000);
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /anaconda/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /anaconda/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /anaconda/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     227                     raise RateLimitError(error_msg, resp)
#     228                 else:
# --> 229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     230
#     231             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
len(MU)
# Out:
# 2640

# %%
import pandas as pd
import numpy as np
MCdf=pd.DataFrame(columns=['user','text','geo','location','followers_count','friends_count','created_at'])  
MUdf=pd.DataFrame(columns=['user','text','geo','location','followers_count','friends_count','created_at'])

# %%
for i in range(len(MU)):
    MUdf.loc[i]={'user':MU[i][0],'text':MU[i][1],'geo':MU[i][2],'location':MU[i][3],'followers_count':MU[i][4],'friends_count':MU[i][5],"created_at":MU[i][6]}
for i in range(len(MC)):
    MCdf.loc[i]={'user':MC[i][0],'text':MC[i][1],'geo':MC[i][2],'location':MC[i][3],'followers_count':MC[i][4],'friends_count':MC[i][5],"created_at":MC[i][6]}

# %%
MCdf.to_csv("MC.csv",index=False,sep=',')
MUdf.to_csv("MU.csv",index=False,sep=',')

# %%
for tweet in tweepy.Cursor(api.search,
                           q='#ocean',
                           since='2016-11-25',
                           until='2016-11-27',
                           geocode='1.3552217,103.8231561,100km',
                           lang='fr').items(10):
    print('Tweet by: @' + tweet.user.screen_name)

# %%
result = api.geo_search(query="USA", granularity="country")

# %%
import json
MU=[]
with open('ManchesterCity1.json', 'r') as f:
    line = f.readlines() # read only the first tweet/line
    print(len(line))
    for i in line:
        tweet= json.loads(i) # load it as Python dict
        MU.append((tweet['user']['screen_name'],tweet['text'],tweet['geo'],tweet['user']['location'],tweet['user']['followers_count'],tweet['user']['friends_count'],tweet['created_at']))
print(len(MU))
# Out:
# 904
# 904

# %%
MU
# Out:
# [('AndyBlacky26',
#   'RT @neilmushing: All picked up safe and sound #fifa18 #Manchester City @benmendy23 @BernardoCSilva @LeroySane19 @ManCity https://t.co/GJUO7…',
#   None,
#   'England',
#   8,
#   39,
#   'Sun Nov 12 02:14:19 +0000 2017'),
#  ('Jobs_in_Man',
#   '1st line IT Support / IT Helpdesk - Manchester City Centre #Manchester #jobs  Apply Now at https://t.co/cT60FRE1nK',
#   None,
#   'Manchester',
#   2626,
#   1921,
#   'Sun Nov 12 01:51:31 +0000 2017'),
#  ('Jadie0503',
#   "RT @Degree53: We've moved! We've grown so much, we needed a new office. We're now based in #Manchester city centre! Take a look!\n\nhttps://t…",
#   None,
#   '',
#   210,
#   400,
#   'Sun Nov 12 01:11:37 +0000 2017'),
#  ('WhitesideDee',
#   'So beautiful, Imagine no religion, but hearing the first Noel....and hoping for peace in a city united in compassio… https://t.co/CgHeDQ48Z4',
#   None,
#   'nanddwhiteside@gmail.com',
#   3643,
#   474,
#   'Sun Nov 12 00:46:14 +0000 2017'),
#  ('mezomefans',
#   "Manchester City to hand Raheem Sterling bumper new deal after England star's stunning start to the season… https://t.co/dzWeHoMPjC",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 23:51:20 +0000 2017'),
#  ('mezomefans',
#   "Manchester City to hand Raheem Sterling bumper new deal after England star's stunning start to the season… https://t.co/lhJA5j7MwU",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 23:49:17 +0000 2017'),
#  ('mezomefans',
#   "''He's got everything'': Ryan Giggs reveals the one Manchester City player he wants at Old Trafford #everything… https://t.co/sCgbJkUzUO",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 23:47:46 +0000 2017'),
#  ('Nineteenforever',
#   'RT @BrutusGold: #Manchester we have good news! Love Train will return early 2018 at a new top notch city centre venue...Stay tuned',
#   None,
#   '',
#   54,
#   264,
#   'Sat Nov 11 23:41:52 +0000 2017'),
#  ('Tamer_Oldboy',
#   'RT @sugarvine: Why Not Try? @cottonopolisNQ #Manchester\nA former tailors studio on Dale Street in the Northern Quarter.\nMenu: https://t.co/…',
#   None,
#   'Manchester, UK',
#   1178,
#   1214,
#   'Sat Nov 11 23:07:01 +0000 2017'),
#  ('WorkManchester',
#   '#ManchesterJobs #Manchester #Jobs Customer Service Advisor - City Centre, Manchester: Customer Service Advisor - Ma… https://t.co/u3YqPTsrtd',
#   None,
#   'Manchester, UK',
#   1006,
#   44,
#   'Sat Nov 11 22:36:07 +0000 2017'),
#  ('ForABetterManch',
#   'RT @ManchesterGOP: Be advised that many roads in #Manchester will be closed due to the city marathon starting at 9am. With temps predicted…',
#   None,
#   'Manchester, NH',
#   62,
#   163,
#   'Sat Nov 11 21:13:05 +0000 2017'),
#  ('ManchesterGOP',
#   'Be advised that many roads in #Manchester will be closed due to the city marathon starting at 9am. With temps predi… https://t.co/D6sfAGI4DN',
#   None,
#   'Manchester, New Hampshire',
#   719,
#   410,
#   'Sat Nov 11 21:12:24 +0000 2017'),
#  ('JobsBall',
#   'Android Developer Needed #Manchester  #City #UK #jobs  Apply Now at https://t.co/6vW1mM9Iok',
#   None,
#   '',
#   1569,
#   1962,
#   'Sat Nov 11 20:51:43 +0000 2017'),
#  ('graciasnapoleon',
#   'RT @davellaneda77: Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en la S…',
#   None,
#   'Capital Federal',
#   91,
#   236,
#   'Sat Nov 11 20:49:34 +0000 2017'),
#  ('JiveRooms',
#   'RT @EasyroommateUK: Never mind the amazing location, look at that view! Who could live in this city centre #flatshare in #manchester ? http…',
#   None,
#   'UK the Jive Land',
#   4691,
#   3719,
#   'Sat Nov 11 20:14:42 +0000 2017'),
#  ('GiovanniDestino',
#   '#Premier #Show: #Manchester City, "zero tituli" in Champions League https://t.co/a89XRXVcbd https://t.co/14qvB67VkZ',
#   None,
#   'Canosa di Puglia, Puglia',
#   192,
#   307,
#   'Sat Nov 11 20:01:49 +0000 2017'),
#  ('Giorgio_Pezzuto',
#   '#Premier #Show: #Manchester City, "zero tituli" in Champions League https://t.co/aKVcZRAIRT https://t.co/FCtrcF5fC7',
#   None,
#   'Napoli, Italia',
#   285,
#   579,
#   'Sat Nov 11 20:01:35 +0000 2017'),
#  ('SN24it',
#   '#Premier #Show: #Manchester City, "zero tituli" in Champions League https://t.co/ZsdByy94Qg https://t.co/dQAdvSgEYW',
#   None,
#   'Napoli, Campania',
#   172,
#   334,
#   'Sat Nov 11 20:01:32 +0000 2017'),
#  ('MaranoAlberto',
#   '#Premier #Show: #Manchester City, "zero tituli" in Champions League https://t.co/TudmEd3abx https://t.co/qGfm9mfIM4',
#   None,
#   '',
#   39,
#   52,
#   'Sat Nov 11 20:01:29 +0000 2017'),
#  ('EasyroommateUK',
#   'Never mind the amazing location, look at that view! Who could live in this city centre #flatshare in #manchester ?… https://t.co/x3u3haniZi',
#   None,
#   'London, England',
#   2902,
#   1984,
#   'Sat Nov 11 20:00:22 +0000 2017'),
#  ('strongbowholic',
#   '@BBCNWT And the fuckers had the audacity to hold their party conference in our great city? Wankers the lot of them.… https://t.co/EY1TfJNNTK',
#   None,
#   '',
#   238,
#   491,
#   'Sat Nov 11 19:41:31 +0000 2017'),
#  ('Humbertswin',
#   'If the #LakeDistrict was a City it would beat Paris into 7th place of the top 10 most visited cities of the world w… https://t.co/G7MeAp0obl',
#   None,
#   'Lake District, England',
#   910,
#   2234,
#   'Sat Nov 11 19:13:07 +0000 2017'),
#  ('LuckyTarget',
#   'I do love my city, until I am reminded that I share it with worthless sacks of shit who do stuff like this @Mobike… https://t.co/FgIWuHRqP4',
#   None,
#   'Manchester',
#   523,
#   236,
#   'Sat Nov 11 19:12:07 +0000 2017'),
#  ('mancmade',
#   'RT @KauriFineFoods: Sounds perfect for you @Opolis53_2 !Another fab #local #label emerging from the #fantastic city that is #Manchester #Ne…',
#   None,
#   'Manchester, England',
#   8817,
#   4920,
#   'Sat Nov 11 19:00:10 +0000 2017'),
#  ('BenParmar1',
#   'RT @Pepe83008360: Spice Lounge, Manchester city centre, now selling gluten free Goa Beer #Manchester #glutenfree #goabeer https://t.co/Vi23…',
#   None,
#   'London, England',
#   54,
#   35,
#   'Sat Nov 11 18:57:48 +0000 2017'),
#  ('KauriFineFoods',
#   'Sounds perfect for you @Opolis53_2 !Another fab #local #label emerging from the #fantastic city that is #Manchester… https://t.co/bpSjoDopb0',
#   None,
#   'Stockport, England',
#   503,
#   276,
#   'Sat Nov 11 18:48:16 +0000 2017'),
#  ('BrutusGold',
#   '#Manchester we have good news! Love Train will return early 2018 at a new top notch city centre venue...Stay tuned',
#   None,
#   'Hire US...W O R L D W I D E',
#   4117,
#   3193,
#   'Sat Nov 11 18:30:13 +0000 2017'),
#  ('BenParmar1',
#   'RT @Pepe83008360: Bollywood Masala, Manchester city centre, now selling gluten free Goa Beer #glutenfree #goabeer #Manchester https://t.co/…',
#   None,
#   'London, England',
#   54,
#   35,
#   'Sat Nov 11 18:20:05 +0000 2017'),
#  ('simon_bushell1',
#   'RT @AndrewPBrooks: Up high over #Manchester filming and photographing the city today. For a new project for @Bruntwood from #NeoMCR https:/…',
#   None,
#   'Macclesfield, England',
#   60,
#   42,
#   'Sat Nov 11 18:11:38 +0000 2017'),
#  ('cordeiro876',
#   '@Jondollson @spain @gail99a @subtel1 @Whistlingghost @DanielM2k18 @Eley01 Yes Jon, been back to @spain again. I was… https://t.co/T78yNDXybe',
#   None,
#   'Greater Manchester, England',
#   949,
#   1065,
#   'Sat Nov 11 17:52:16 +0000 2017'),
#  ('JohnM_foto',
#   'Manchester central library arches #IRPhotographyPosse #fotografia #city #bnwphotography #bnw_city #bnw #manchester https://t.co/KBV5hUJXpD',
#   None,
#   'Lancashire',
#   8514,
#   7044,
#   'Sat Nov 11 17:29:32 +0000 2017'),
#  ('remiakande',
#   'Selling one 1xtra live ticket (Block 106) for tonight, based in Manchester City Centre. DM for details \n\n#1xtralive… https://t.co/bOlYaePk7O',
#   None,
#   'Instagram/Snapchat @remiakande',
#   2352,
#   1409,
#   'Sat Nov 11 16:55:36 +0000 2017'),
#  ('yourmovemag',
#   '"We were among the first to bring city centre living to #Liverpool and #Manchester".\nhttps://t.co/1NjvOZwmfz',
#   None,
#   'Liverpool',
#   4208,
#   1270,
#   'Sat Nov 11 16:45:01 +0000 2017'),
#  ('RubenRojo86',
#   'RT @davellaneda77: Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en la S…',
#   None,
#   'Mendoza, Argentina',
#   91,
#   191,
#   'Sat Nov 11 16:41:49 +0000 2017'),
#  ('thomaskolster',
#   'I always travel w my running shoes - and this must be one of the cooler city runs I’ve done #Manchester https://t.co/0SgaHOACva',
#   None,
#   'Worldwide ',
#   6204,
#   2262,
#   'Sat Nov 11 16:37:36 +0000 2017'),
#  ('CHARLYROJO666',
#   'RT @davellaneda77: Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en la S…',
#   None,
#   'Ciudad Autónoma de Buenos Aire',
#   1812,
#   2804,
#   'Sat Nov 11 16:31:21 +0000 2017'),
#  ('MatBF2',
#   'RT @davellaneda77: Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en la S…',
#   None,
#   'Mar del Plata',
#   77,
#   79,
#   'Sat Nov 11 16:08:10 +0000 2017'),
#  ('MatiasCaastillo',
#   'RT @davellaneda77: Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en la S…',
#   None,
#   '※ Real Madrid ※ CABJ💙💛💙 ※',
#   1212,
#   846,
#   'Sat Nov 11 16:04:14 +0000 2017'),
#  ('davellaneda77',
#   'Se pelean por Agüero. Es un fenomenal delantero, lo dejó más que claro en el #Manchester City y alcanzó a Crespo en… https://t.co/8yZM3W7jki',
#   None,
#   'Buenos Aires',
#   30447,
#   632,
#   'Sat Nov 11 16:00:35 +0000 2017'),
#  ('JiveManchester',
#   'RT @robinmuirhead: My City has changed a bit, just more bling #Manchester https://t.co/PuyViYWGcz',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Sat Nov 11 15:34:06 +0000 2017'),
#  ('davlsmatty',
#   'RT @robinmuirhead: My City has changed a bit, just more bling #Manchester https://t.co/PuyViYWGcz',
#   None,
#   'Loudoun County VA',
#   40,
#   1444,
#   'Sat Nov 11 15:27:43 +0000 2017'),
#  ('myfoodfantasy69',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester, England',
#   3734,
#   2826,
#   'Sat Nov 11 15:12:40 +0000 2017'),
#  ('robinmuirhead',
#   'My City has changed a bit, just more bling #Manchester https://t.co/PuyViYWGcz',
#   None,
#   'United Kingdom',
#   9136,
#   7622,
#   'Sat Nov 11 15:12:06 +0000 2017'),
#  ('mezomefans',
#   'Manchester City Striker Jesus Admits to Getting Up Early to Play Football in Sao Paulo Prison #manchester #striker… https://t.co/eWpo5ogmRS',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 15:04:14 +0000 2017'),
#  ('DT_Ardwick',
#   'Well done to those pupils that represented the school last week in athletics at Sports City #Manchester https://t.co/hjHdJG3cur',
#   None,
#   '',
#   238,
#   28,
#   'Sat Nov 11 15:02:38 +0000 2017'),
#  ('street_stage',
#   'Being located in a fantastic city always helps a business. Luckily for us, we are part of Manchester! ❤️🎶🇬🇧… https://t.co/G0Q3vixljn',
#   None,
#   'Manchester, England',
#   2,
#   5,
#   'Sat Nov 11 14:38:00 +0000 2017'),
#  ('UniStudentLets',
#   '#Manchester earns prestigious Unesco City of Literature status. #student\n\nhttps://t.co/351YudZJdD',
#   None,
#   'UK',
#   916,
#   1675,
#   'Sat Nov 11 14:32:53 +0000 2017'),
#  ('KollolRoy1987',
#   'Latest,#Tottenham Hotspur are interested in #Manchester City 16-year-old striker Bobby Duncan, according to The Times.',
#   None,
#   'Haora, India',
#   13,
#   63,
#   'Sat Nov 11 14:02:46 +0000 2017'),
#  ('JCPinManchester',
#   '.@Tesla are holding a Sales Recruitment Event in #Manchester city centre November 28th #Model3 Book here:… https://t.co/bT4b8xyeUf',
#   None,
#   'Manchester, UK',
#   10598,
#   645,
#   'Sat Nov 11 14:01:37 +0000 2017'),
#  ('CjGreenham',
#   'For a city with so much vegan availability it was really disappointing to see so little food options for vegans, on… https://t.co/T8gTrnkARL',
#   None,
#   'Manchester, England',
#   163,
#   172,
#   'Sat Nov 11 13:52:53 +0000 2017'),
#  ('_abitdaft',
#   'Manchester City Council Christmas Advert 2017. #ilovemanchester #bee #Manchester #lovemycity  https://t.co/3KFDFMJAct',
#   None,
#   'sunny Manchester ',
#   1082,
#   659,
#   'Sat Nov 11 13:45:37 +0000 2017'),
#  ('LostEvent_MAN',
#   'Manchester City Women take on Bristol City  #Manchester - https://t.co/7WXPuxvoHD https://t.co/SoojXa5aOJ',
#   None,
#   'Manchester',
#   1566,
#   535,
#   'Sat Nov 11 13:25:35 +0000 2017'),
#  ('Matt_Attridge',
#   'German wine 🍷 tasting at the @Holunabell at Event City #manchester #eventcity #food&amp;drinkshow… https://t.co/xDLjlLXrEv',
#   {'coordinates': [53.4660786, -2.33966609], 'type': 'Point'},
#   'Manchester',
#   815,
#   2288,
#   'Sat Nov 11 13:20:19 +0000 2017'),
#  ('smartercitymcr',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, UK',
#   4362,
#   464,
#   'Sat Nov 11 13:06:18 +0000 2017'),
#  ('MarvelKitchenUK',
#   "#Marvelkitchen is a proud resident of #Manchester a great city in the #UK. We will never forget our roots - and we'… https://t.co/pPHHMqV1oh",
#   None,
#   'Manchester, England',
#   138,
#   8,
#   'Sat Nov 11 12:01:47 +0000 2017'),
#  ('StaybridgeManc',
#   'Did you know that Soreen and Vimto were both discovered in #Manchester? \nFind out what else was invented in our fan… https://t.co/EZLyNHA2Tr',
#   None,
#   'Manchester, England',
#   849,
#   1264,
#   'Sat Nov 11 12:00:14 +0000 2017'),
#  ('ChrisHames11',
#   'Man carrying his son out of Piccadilly station: "You\'re in Manchester kid... just look at this city" #Manchester',
#   None,
#   'Manchester/Sheffield',
#   215,
#   353,
#   'Sat Nov 11 11:45:09 +0000 2017'),
#  ('s6lty1',
#   'God bless those who sacrificed everything for us to live our lives freely 🙏 perfect minutes silence in our great ci… https://t.co/KUw64DAqn8',
#   None,
#   'Royal Sale, England',
#   375,
#   366,
#   'Sat Nov 11 11:26:42 +0000 2017'),
#  ('sugarvine',
#   'Why Not Try? @cottonopolisNQ #Manchester\nA former tailors studio on Dale Street in the Northern Quarter.\nMenu:… https://t.co/GMUwMEwlYk',
#   None,
#   'UK',
#   16730,
#   5261,
#   'Sat Nov 11 11:05:15 +0000 2017'),
#  ('RyadMd',
#   'ابسط واجمل إعلان للكريسمس في مانشيستر!\nMy favorite city of the world, I miss it. #Manchester🐝 https://t.co/FFoxNY9z1Q',
#   None,
#   'Saudi Arabia',
#   518,
#   122,
#   'Sat Nov 11 10:48:49 +0000 2017'),
#  ('DeFruitBar1',
#   'Manchester city vegan fest 2days LETS GOO!!!!##\n#manchester https://t.co/k3n4oJd9sr',
#   None,
#   'West Midlands, England',
#   35,
#   40,
#   'Sat Nov 11 10:37:52 +0000 2017'),
#  ('alecherron',
#   "So has @MobikeUK in #Manchester  finished now? None available in the whole city though I'm sure I saw one just the other day.",
#   None,
#   'Manchester ',
#   823,
#   495,
#   'Sat Nov 11 10:14:40 +0000 2017'),
#  ('StaybridgeManc',
#   "Once our #hotel opens in #Manchester we'll feature a choice of 7 meeting rooms with over 200 delegate space availab… https://t.co/momsQvUwTZ",
#   None,
#   'Manchester, England',
#   849,
#   1264,
#   'Sat Nov 11 10:00:03 +0000 2017'),
#  ('leossie',
#   '- Manchester -\n.\n.\n#travel #uk #manchester #riverside #city #iphone7 https://t.co/sM6DHWodBB https://t.co/hA3xyDEQFD',
#   None,
#   'Lyon, France',
#   524,
#   1842,
#   'Sat Nov 11 09:56:40 +0000 2017'),
#  ('APortionOfMum',
#   "Stuck for ideas to keep the kids entertained this weekend? Some great ideas of 'things to do' in and around… https://t.co/xzbXYES6RR",
#   None,
#   'Altrincham, Greater Manchester, United Kingdom',
#   208,
#   134,
#   'Sat Nov 11 09:55:05 +0000 2017'),
#  ('AndrewPBrooks',
#   'Up high over #Manchester filming and photographing the city today. For a new project for @Bruntwood from #NeoMCR https://t.co/rPPWGeqXeU',
#   None,
#   'Manchester UK',
#   5123,
#   2771,
#   'Sat Nov 11 09:16:52 +0000 2017'),
#  ('NewBaileyM3',
#   "We love our central location, it makes Saturday shopping in the City a breeze! What's more? Our NCP makes parking e… https://t.co/YaFZ628FFL",
#   None,
#   'M3 ',
#   2299,
#   972,
#   'Sat Nov 11 08:25:02 +0000 2017'),
#  ('mezomefans',
#   "Chelsea can be European champions —\xa0and Manchester City won't be far behind #chelsea #european #champions… https://t.co/mJzJ8j35au",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 07:47:09 +0000 2017'),
#  ('JiveManchester',
#   'RT @TweetbugPR: In the beautiful #city of #Manchester tonight... leaving in the early hours to go to #NorthWales to climb #Snowdonia 😊 #mou…',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Sat Nov 11 06:36:05 +0000 2017'),
#  ('JiveManchester',
#   'RT @KG_womanarch: For those who enjoy the season festivities, I recommend you visit #Manchester city centre in the coming weeks to enjoy th…',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Sat Nov 11 06:12:04 +0000 2017'),
#  ('mezomefans',
#   "Arsenal, Chelsea, Everton and Manchester City 'keeping tabs on Luke Shaw's situation at Manchester United' #arsenal… https://t.co/CzJjoYj3WW",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 06:06:12 +0000 2017'),
#  ('mezomefans',
#   "Arsenal, Chelsea, Everton and Manchester City 'keeping tabs on Luke Shaw's situation at Manchester United' #arsenal… https://t.co/Rm83uMdoGk",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 11 06:03:19 +0000 2017'),
#  ('JiveRooms',
#   'RT @EasyroommateUK: #Houseshare of the day 🏠 : A simple and low-cost flatshare just outside of #manchester city centre https://t.co/18elJU8…',
#   None,
#   'UK the Jive Land',
#   4691,
#   3719,
#   'Sat Nov 11 05:14:10 +0000 2017'),
#  ('JiveManchester',
#   'RT @jackiecrozier: Why you should come &amp; visit our great city this Christmas #Manchester #McrChristmas 🐝 🎅🏻🐝🎅🏻 https://t.co/eEkeWSsjPL',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Sat Nov 11 05:03:04 +0000 2017'),
#  ('Abagail_OhMY',
#   '@amazon 5/ #Manchester (not the English City) #Luggage. Luggage offerings AND -PRICES- in #Australia are ABYSMAL!… https://t.co/do0U5jpYzk',
#   None,
#   'Melb/Syd/Bris',
#   310,
#   393,
#   'Sat Nov 11 04:23:09 +0000 2017'),
#  ('MercyHomesUK',
#   'https://t.co/9jsKsi983b\nManchester City Centre\n7% Assured Net Rental Return\nPrices from £84,000 #btl #manchester… https://t.co/FlTzUMVIGq',
#   None,
#   'London, New York, Lagos, Dubai',
#   961,
#   433,
#   'Sat Nov 11 00:14:29 +0000 2017'),
#  ('mrwilliamjensen',
#   'RT @jackiecrozier: Why you should come &amp; visit our great city this Christmas #Manchester #McrChristmas 🐝 🎅🏻🐝🎅🏻 https://t.co/eEkeWSsjPL',
#   None,
#   'Manchester, UK',
#   162,
#   85,
#   'Sat Nov 11 00:06:08 +0000 2017'),
#  ('KG_womanarch',
#   'For those who enjoy the season festivities, I recommend you visit #Manchester city centre in the coming weeks to en… https://t.co/O4ucqU4dIo',
#   None,
#   'London, England',
#   590,
#   1415,
#   'Fri Nov 10 23:29:22 +0000 2017'),
#  ('DayRooney',
#   'I love my city SO MUCH! 😍The energy and peaceful ambiance up here is unreal! #Manchester we💙you!☺️ Manchester... We… https://t.co/QBnvTromPi',
#   None,
#   'Harpurhey 🐝0161',
#   11074,
#   6920,
#   'Fri Nov 10 23:16:48 +0000 2017'),
#  ('benjgray',
#   'Manchester City Council Christmas Advert 2017 #Manchester  https://t.co/OAAllA6B2T',
#   None,
#   'Cheshire',
#   679,
#   1485,
#   'Fri Nov 10 23:15:10 +0000 2017'),
#  ('TweetbugPR',
#   'In the beautiful #city of #Manchester tonight... leaving in the early hours to go to #NorthWales to climb… https://t.co/OC5P98IOdz',
#   None,
#   'London/ Cardiff ',
#   662,
#   1613,
#   'Fri Nov 10 23:13:09 +0000 2017'),
#  ('TowerBlockRadio',
#   'https://t.co/73fgdyrA8O  LIVE &gt;&gt; Snowman #np @MRGOLDIE #RIPDianeCharlemagne - Inner City Life #DnB &amp; more.… https://t.co/krutkz0Q0l',
#   None,
#   'Manchester UK',
#   1637,
#   274,
#   'Fri Nov 10 23:11:03 +0000 2017'),
#  ('DrummerBoyReece',
#   'Not enough noise and too much racket ... #manchester #city #the1975 @ Central Manchester,… https://t.co/w9EWkzsx4t',
#   {'coordinates': [53.47822315, -2.23733163], 'type': 'Point'},
#   '',
#   109,
#   164,
#   'Fri Nov 10 22:57:36 +0000 2017'),
#  ('Sandracsl1964',
#   'RT @gracebeaudale: My city ❤️🎅🏼🎄 #manchester #manchesterchristmasmarkets #christmas #mycity #home https://t.co/P12NRzgUp8',
#   None,
#   'Stockport',
#   659,
#   1453,
#   'Fri Nov 10 22:48:27 +0000 2017'),
#  ('jackiecrozier',
#   'Why you should come &amp; visit our great city this Christmas #Manchester #McrChristmas 🐝 🎅🏻🐝🎅🏻 https://t.co/eEkeWSsjPL',
#   None,
#   'manchester',
#   6682,
#   549,
#   'Fri Nov 10 22:12:57 +0000 2017'),
#  ('TowerBlockRadio',
#   'https://t.co/73fgdyrA8O LIVE &gt;&gt; Snowman #np @iAmSpokazi - Riding Round The City #Dance #Soul #HipHop &amp;  more.… https://t.co/n37VUvH0gH',
#   None,
#   'Manchester UK',
#   1637,
#   274,
#   'Fri Nov 10 21:58:36 +0000 2017'),
#  ('Manc_restaurant',
#   'https://t.co/Q3MV4e3uWV #manchester #restaurant #jobs It was once a bustling train station... now this site on the… https://t.co/vzRDY8nVFg',
#   None,
#   'Manchester, Cheshire',
#   90,
#   73,
#   'Fri Nov 10 21:35:06 +0000 2017'),
#  ('markcnichols',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'North West, England',
#   367,
#   748,
#   'Fri Nov 10 21:09:41 +0000 2017'),
#  ('schestowitz',
#   'Thankfully in #manchester we turn away cars from City Centre and electric tram expands, more buses now hybrid https://t.co/jTmQLiyEi6',
#   None,
#   'North Pole',
#   7603,
#   989,
#   'Fri Nov 10 20:58:34 +0000 2017'),
#  ('Pepe83008360',
#   'Bollywood Masala, Manchester city centre, now selling gluten free Goa Beer #glutenfree #goabeer #Manchester https://t.co/SJwgeueW1v',
#   None,
#   '',
#   35,
#   4,
#   'Fri Nov 10 20:22:47 +0000 2017'),
#  ('WorkManchester',
#   '#ManchesterJobs #Manchester #Jobs Principal Electrical Engineer, Manchester: Principal Electrical Engineer Manchest… https://t.co/Us6Ks0k41w',
#   None,
#   'Manchester, UK',
#   1006,
#   44,
#   'Fri Nov 10 20:21:33 +0000 2017'),
#  ('mezomefans',
#   'Dries Mertens Hints at Premier League Move as Napoli Star Insists Manchester City Are Not Unbeatable #dries… https://t.co/MVECojfjgi',
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 10 19:11:19 +0000 2017'),
#  ('mezomefans',
#   'Manchester City Transfer News: Latest Rumours on Sergi Roberto and Bobby Duncan #manchester #transfer #latest… https://t.co/uLrZowIqje',
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 10 19:10:10 +0000 2017'),
#  ('mezomefans',
#   'Manchester City Transfer News: Latest Rumours on Sergi Roberto and Bobby Duncan #manchester #transfer #latest… https://t.co/MaHAypCrFz',
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 10 19:10:08 +0000 2017'),
#  ('mezomefans',
#   'Dries Mertens Hints at Premier League Move as Napoli Star Insists Manchester City Are Not Unbeatable #dries… https://t.co/knSHXeMsM6',
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 10 19:10:07 +0000 2017'),
#  ('Pepe83008360',
#   'Spice Lounge, Manchester city centre, now selling gluten free Goa Beer #Manchester #glutenfree #goabeer https://t.co/Vi23DPRk5D',
#   None,
#   '',
#   35,
#   4,
#   'Fri Nov 10 19:05:01 +0000 2017'),
#  ('LuckyTarget',
#   'Best restaurants in #Manchester City Centre for #vegetarian food? Anyone?',
#   None,
#   'Manchester',
#   523,
#   236,
#   'Fri Nov 10 18:48:27 +0000 2017'),
#  ('jonnystannard',
#   'RT @AinscowThe: Having your works #Christmasparty in #Manchester and need a place to stay with a Roof top bar and stunning views over the c…',
#   None,
#   'ÜT: 38.8919867,1.406427',
#   1462,
#   2127,
#   'Fri Nov 10 18:40:15 +0000 2017'),
#  ('AinscowThe',
#   'Having your works #Christmasparty in #Manchester and need a place to stay with a Roof top bar and stunning views ov… https://t.co/tVLGDXsWAn',
#   None,
#   'Trinity Way Salford M3 5HY',
#   896,
#   565,
#   'Fri Nov 10 18:26:41 +0000 2017'),
#  ('JiveManchester',
#   "RT @startupstowers: Is #Manchester replacing London as THE start-up city? From textiles to tech philes, we look at Manchester's business po…",
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Fri Nov 10 18:14:06 +0000 2017'),
#  ('venturescapeuk',
#   "RT @startupstowers: Is #Manchester replacing London as THE start-up city? From textiles to tech philes, we look at Manchester's business po…",
#   None,
#   'London, England',
#   54,
#   147,
#   'Fri Nov 10 18:08:58 +0000 2017'),
#  ('EmmaMcrDig',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, England',
#   95,
#   191,
#   'Fri Nov 10 17:59:32 +0000 2017'),
#  ('MedicineGov',
#   "@NHS 🐝\n#Manchester #UK #England \n\n'If this tweet was the #flu virus I wonder how long it would take to get around t… https://t.co/deJqmrSIRu",
#   None,
#   'ABOUT @MEDICINEGOV Health: Government Affairs, Policy, Strategy, MedEd & Communications. Social, Video & Digital Media. UK. private business',
#   5053,
#   4725,
#   'Fri Nov 10 17:24:15 +0000 2017'),
#  ('lw00l',
#   "RT @startupstowers: Is #Manchester replacing London as THE start-up city? From textiles to tech philes, we look at Manchester's business po…",
#   None,
#   'Berkshire UK',
#   1116,
#   1167,
#   'Fri Nov 10 17:18:46 +0000 2017'),
#  ('startupstowers',
#   "Is #Manchester replacing London as THE start-up city? From textiles to tech philes, we look at Manchester's busines… https://t.co/3eq0mA39QW",
#   None,
#   'London, England',
#   70618,
#   9234,
#   'Fri Nov 10 17:10:31 +0000 2017'),
#  ('Iam_njd',
#   'The city council has done such a good job of making the markets as secure as possible with barriers and entry scanning 💃🏼🎄❤️👌🏼 #Manchester',
#   None,
#   '',
#   1620,
#   365,
#   'Fri Nov 10 16:49:28 +0000 2017'),
#  ('AWBPhotography',
#   'Sunset City☀️🌆 this was the first shot before the sky went blue and I grabbed the previous shot I posted. #WeAreMCR… https://t.co/Wukq0EiDp3',
#   None,
#   'Manchester',
#   465,
#   251,
#   'Fri Nov 10 16:43:22 +0000 2017'),
#  ('e_marketing_com',
#   'Just picked #Manchester City as my top scoring player to win the jackpot at https://t.co/BQVlNDOkAv #contest #BetStarsJackpots',
#   None,
#   '@Parfait_vivre',
#   1093,
#   1212,
#   'Fri Nov 10 16:29:16 +0000 2017'),
#  ('DANIELJAMESREC',
#   'RT @gracebeaudale: My city ❤️🎅🏼🎄 #manchester #manchesterchristmasmarkets #christmas #mycity #home https://t.co/P12NRzgUp8',
#   None,
#   'Nottingham, England',
#   1877,
#   5001,
#   'Fri Nov 10 16:19:43 +0000 2017'),
#  ('TheNickLongBomb',
#   'Just got back from #Manchester after watching @runjewels, genuinley one of my favourite live acts. Also, shout out… https://t.co/thRqoZ7kcJ',
#   None,
#   'Bristol',
#   247,
#   607,
#   'Fri Nov 10 15:51:47 +0000 2017'),
#  ('yourmovemag',
#   '"We were among the first to bring city centre living to #Liverpool and #Manchester".\nhttps://t.co/1NjvOZwmfz',
#   None,
#   'Liverpool',
#   4208,
#   1270,
#   'Fri Nov 10 15:45:01 +0000 2017'),
#  ('TheAtlasBar',
#   'We are loving #Manchester City Councils #Christmas clip https://t.co/CI4zK0Ghyf',
#   None,
#   ' Deansgate, Manchester, M3 4LY',
#   3663,
#   2192,
#   'Fri Nov 10 15:12:31 +0000 2017'),
#  ('EasyroommateUK',
#   '#Houseshare of the day 🏠 : A simple and low-cost flatshare just outside of #manchester city centre… https://t.co/QUqYmvNaga',
#   None,
#   'London, England',
#   2902,
#   1984,
#   'Fri Nov 10 15:01:02 +0000 2017'),
#  ('NewBaileyM3',
#   "#NewBailey is #centrally located within the #heart of #Manchester's thriving #City, download our #brochure here:… https://t.co/HcpwHe197k",
#   None,
#   'M3 ',
#   2299,
#   972,
#   'Fri Nov 10 14:50:05 +0000 2017'),
#  ('Citytowermcr',
#   "No matter where you are in #Manchester, or what time of day it is, you'll always spot City Tower 🏙\n.\n.\n.\n#architec…… https://t.co/KEW5TuAqmt",
#   None,
#   'Manchester, England',
#   1144,
#   1164,
#   'Fri Nov 10 14:43:34 +0000 2017'),
#  ('LiveLetBuy',
#   '#Manchester earns prestigious #UNESCO City of #Literature status\nhttps://t.co/DwR7Gv4FJx',
#   None,
#   'London, England',
#   958,
#   2741,
#   'Fri Nov 10 14:26:30 +0000 2017'),
#  ('gracebeaudale',
#   'My city ❤️🎅🏼🎄 #manchester #manchesterchristmasmarkets #christmas #mycity #home https://t.co/P12NRzgUp8',
#   None,
#   'Saddleworth',
#   1516,
#   253,
#   'Fri Nov 10 14:17:51 +0000 2017'),
#  ('ChicBloggers',
#   "RT @GoSochal: Ancient Manchester - 6 of the city's oldest buildings! https://t.co/tCF7kjtHT0  #history #lbloggers #WeBlogNorth #manchester…",
#   None,
#   '',
#   1050,
#   1,
#   'Fri Nov 10 14:00:02 +0000 2017'),
#  ('rtlbloggers',
#   "RT @GoSochal: Ancient Manchester - 6 of the city's oldest buildings! https://t.co/tCF7kjtHT0  #history #lbloggers #WeBlogNorth #manchester…",
#   None,
#   '',
#   631,
#   1,
#   'Fri Nov 10 14:00:02 +0000 2017'),
#  ('FemBloggers',
#   "RT @GoSochal: Ancient Manchester - 6 of the city's oldest buildings! https://t.co/tCF7kjtHT0  #history #lbloggers #WeBlogNorth #manchester…",
#   None,
#   '',
#   1358,
#   1,
#   'Fri Nov 10 14:00:02 +0000 2017'),
#  ('GoSochal',
#   "Ancient Manchester - 6 of the city's oldest buildings! https://t.co/tCF7kjtHT0  #history #lbloggers #WeBlogNorth… https://t.co/5FiOpMh4sV",
#   None,
#   'Manchester, England',
#   3654,
#   1229,
#   'Fri Nov 10 13:59:04 +0000 2017'),
#  ('HogansLeeds',
#   'Which city leads? #leeds #manchester or #Newcastle https://t.co/aarjGjmVGY',
#   None,
#   'Leeds',
#   874,
#   1513,
#   'Fri Nov 10 13:50:07 +0000 2017'),
#  ('Forsh',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, UK',
#   26295,
#   26947,
#   'Fri Nov 10 13:31:40 +0000 2017'),
#  ('manmetuni_int',
#   'Here is some useful travel information for getting around #Manchester!\n\nhttps://t.co/C6TfJnMLmy #Transport #City… https://t.co/UBwqvNu8R8',
#   None,
#   "Student's Hub, Manchester",
#   1883,
#   320,
#   'Fri Nov 10 13:30:13 +0000 2017'),
#  ('bibliotechLib',
#   '#Manchester named Unesco City of Literature. Read more about the city here: https://t.co/Y1F5GvbGMi',
#   None,
#   'London, England',
#   762,
#   1202,
#   'Fri Nov 10 13:24:34 +0000 2017'),
#  ('SmartWorksGM',
#   "💥Don't forget💥Fashion Sale tomorrow💥Manchester City Centre | 3 min walk from Market Street. All welcome | See you t… https://t.co/nYaRDNEmhT",
#   None,
#   'Manchester',
#   995,
#   1108,
#   'Fri Nov 10 12:55:26 +0000 2017'),
#  ('JiveManchester',
#   'RT @NewBaileyM3: One New Bailey in the heart of the city’s business district, immediately adjacent to Spinningfields #Manchester #OfficeSpa…',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Fri Nov 10 12:36:05 +0000 2017'),
#  ('NewBaileyM3',
#   'One New Bailey in the heart of the city’s business district, immediately adjacent to Spinningfields #Manchester #OfficeSpace',
#   None,
#   'M3 ',
#   2299,
#   972,
#   'Fri Nov 10 12:30:26 +0000 2017'),
#  ('ZoukTeaBar',
#   "RT @sugarvine: Multi-award-winning @ZoukTeaBar \nopposite the @BBC studios on #Manchester's Oxford Road\nSee The Menu: https://t.co/e6GXnPTlC…",
#   None,
#   'Manchester & Bradford',
#   5445,
#   3081,
#   'Fri Nov 10 12:29:10 +0000 2017'),
#  ('charlieschouten',
#   "Construction on second phase of #Manchester's Cycle City initiative not due to start till spring next year - delay… https://t.co/mwvXsriwx1",
#   None,
#   'Manchester, England',
#   2457,
#   1085,
#   'Fri Nov 10 12:23:42 +0000 2017'),
#  ('Manc_restaurant',
#   'https://t.co/Q3MV4e3uWV #manchester #restaurant #jobs Smoke seen across city centre after fire in Northern Quarter… https://t.co/qz7swQmzyK',
#   None,
#   'Manchester, Cheshire',
#   90,
#   73,
#   'Fri Nov 10 12:15:04 +0000 2017'),
#  ('mezomefans',
#   'Arsenal keeping tabs on Manchester City starlet Bobby Duncan - the cousin of Liverpool legend Steven Gerrard… https://t.co/KkAzeJjagS',
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 10 11:53:30 +0000 2017'),
#  ('NFLShopEurope',
#   'RT @NFLGirlUK: Come to the #NFLUKFanMeetUp in #Manchester City centre on Saturday 16 December from 7pm. It’s our Christmas get together AND…',
#   None,
#   '',
#   10195,
#   253,
#   'Fri Nov 10 11:47:49 +0000 2017'),
#  ('JiveManchester',
#   'RT @DHC_Chennai: #Manchester City of history: First steam #Railway @ManchesterUniv birthplace of #communism #socialism #suffragette #nuclea…',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Fri Nov 10 11:41:04 +0000 2017'),
#  ('DHC_Chennai',
#   '#Manchester City of history: First steam #Railway @ManchesterUniv birthplace of #communism #socialism #suffragette… https://t.co/rocguZgtDL',
#   None,
#   'Chennai',
#   3110,
#   1367,
#   'Fri Nov 10 11:35:55 +0000 2017'),
#  ('acookebruntwood',
#   "And it's not just Manchester city centre we see this trend..... exciting things in the pipeline outside the inner r… https://t.co/fF4EW2YvXt",
#   None,
#   'North West, England',
#   53,
#   134,
#   'Fri Nov 10 11:32:37 +0000 2017'),
#  ('ConnectionsMCR',
#   'We are looking for an #Administrator on a #temporary 3 month contract. \nThis position is based in #Manchester City… https://t.co/yerZxCGM9l',
#   None,
#   'Manchester, England',
#   1384,
#   1559,
#   'Fri Nov 10 11:24:46 +0000 2017'),
#  ('StayInnHotel',
#   'Located moments away from #Manchester city centre, @StayInnHotel offers a wide range of #rooms and #services to acc… https://t.co/T0PtbthquS',
#   None,
#   'Manchester',
#   719,
#   445,
#   'Fri Nov 10 11:14:56 +0000 2017'),
#  ('tmhackett',
#   'RT @IUC_EU: #Manchester used social media to ask citizens what their dream for the city would be. They then used this information to inform…',
#   None,
#   'Medellín, Mexico City, London ',
#   608,
#   978,
#   'Fri Nov 10 11:14:13 +0000 2017'),
#  ('PatriziaMarani',
#   'RT @IUC_EU: #Manchester used social media to ask citizens what their dream for the city would be. They then used this information to inform…',
#   None,
#   'Italy',
#   55,
#   120,
#   'Fri Nov 10 11:09:18 +0000 2017'),
#  ('huddledigital',
#   '#Manchester to decide on digital narrative as #technology sector expands in the city. What version of #digital succ… https://t.co/96EYTQLS3E',
#   None,
#   'Manchester, UK',
#   353,
#   381,
#   'Fri Nov 10 11:09:00 +0000 2017'),
#  ('jorjao90',
#   'RT @IUC_EU: #Manchester used social media to ask citizens what their dream for the city would be. They then used this information to inform…',
#   None,
#   'Colima, México',
#   730,
#   2760,
#   'Fri Nov 10 11:00:48 +0000 2017'),
#  ('thisisinnercity',
#   "On sale now! @fredvgrafix have announced a show at #Manchester's @DeafInstitute in February! Tickets:… https://t.co/BF32Ayb47O",
#   None,
#   'United Kingdom',
#   463,
#   493,
#   'Fri Nov 10 11:00:02 +0000 2017'),
#  ('nathanjw9',
#   'Hazy Manchester, from a not so flattering angle.\n•\n#Hazy #City #Sky #Morning #View #Manchester… https://t.co/5wGZqFnXer',
#   None,
#   'Manchester',
#   459,
#   1135,
#   'Fri Nov 10 10:20:24 +0000 2017'),
#  ('IUC_EU',
#   '#Manchester used social media to ask citizens what their dream for the city would be. They then used this informati… https://t.co/g7ROUcqj3N',
#   None,
#   '',
#   169,
#   67,
#   'Fri Nov 10 10:16:46 +0000 2017'),
#  ('Space48ers',
#   'The #Manchester #Christmas markets have returned to the city today for 41 days of festivities! 🎅 https://t.co/YQVyxFldEk',
#   None,
#   'Manchester & London, UK',
#   2434,
#   1034,
#   'Fri Nov 10 09:32:41 +0000 2017'),
#  ('HFMA_UK',
#   'Manchester lights the way - The devolved city region’s health and social services integration is beginning to get s… https://t.co/BzfgMxIC4n',
#   None,
#   'United Kingdom',
#   2525,
#   417,
#   'Fri Nov 10 09:26:40 +0000 2017'),
#  ('lockwoodwriter',
#   'RT @riewriting: Great to see @TheGEAcademy here in #Manchester #UNESCO City of Literature. https://t.co/s03NI3ZGUy',
#   None,
#   'West Wittering, England',
#   3386,
#   4172,
#   'Fri Nov 10 09:21:52 +0000 2017'),
#  ('pmadamson68',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   '',
#   49,
#   237,
#   'Fri Nov 10 09:15:18 +0000 2017'),
#  ('emmajgreenwood',
#   'RT @riewriting: Great to see @TheGEAcademy here in #Manchester #UNESCO City of Literature. https://t.co/s03NI3ZGUy',
#   None,
#   '',
#   1279,
#   367,
#   'Fri Nov 10 09:05:50 +0000 2017'),
#  ('MForsu',
#   '@ideal_home_show #bijourious #gifts #giftwrap #giftwrapping #giftideas #wrappingpaper #wrappinggifts #manchester… https://t.co/CeP9Ww8r8O',
#   None,
#   'Manchester, England',
#   15,
#   5,
#   'Fri Nov 10 08:57:18 +0000 2017'),
#  ('UniteCommSEL',
#   'RT @themediafund: Who is this city for? - @meteorjsman https://t.co/GJ8NZBc98o #Manchester #IndyMedia https://t.co/iYoxTd4lgJ',
#   None,
#   'London, England',
#   3764,
#   4549,
#   'Fri Nov 10 08:08:53 +0000 2017'),
#  ('FreeCodeCampMCR',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, England',
#   109,
#   98,
#   'Fri Nov 10 08:05:27 +0000 2017'),
#  ('JD_aka_Techy',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester,UK',
#   65,
#   147,
#   'Fri Nov 10 08:05:27 +0000 2017'),
#  ('themediafund',
#   'Who is this city for? - @meteorjsman https://t.co/GJ8NZBc98o #Manchester #IndyMedia https://t.co/iYoxTd4lgJ',
#   None,
#   'UK',
#   1243,
#   2660,
#   'Fri Nov 10 08:01:09 +0000 2017'),
#  ('JiveManchester',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Fri Nov 10 06:45:05 +0000 2017'),
#  ('ghanshyamn',
#   '@DHC_Chennai a warm welcome to City of innovation #Manchester look forward to meeting you',
#   None,
#   'Manchester',
#   527,
#   589,
#   'Fri Nov 10 06:12:52 +0000 2017'),
#  ('JohnM_foto',
#   'Manchester central library arches #IRPhotographyPosse #fotografia #city #bnwphotography #bnw_city #bnw #manchester https://t.co/KBV5hUJXpD',
#   None,
#   'Lancashire',
#   8514,
#   7044,
#   'Fri Nov 10 05:15:53 +0000 2017'),
#  ('Charlesfrize',
#   '#Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester,England',
#   16008,
#   9780,
#   'Fri Nov 10 04:40:58 +0000 2017'),
#  ('JiveManchester',
#   'RT @UoMSALC: As @newwritingMCR turns 10 we look at the impact its had in shaping #Manchester #Cityofliterature: https://t.co/IJFJV1e31g #Uo…',
#   None,
#   'Manchester, England',
#   6178,
#   329,
#   'Fri Nov 10 04:32:03 +0000 2017'),
#  ('titrespresse',
#   '(https://t.co/eljTlNViUE) #Manchester #City\xa0: Guardiola, Gabriel Jesus… La mise au point d’Aguero..… https://t.co/lozQNAi7Og',
#   None,
#   '',
#   2137,
#   300,
#   'Fri Nov 10 04:06:39 +0000 2017'),
#  ('ManUInfoTweets1',
#   'Race for £62m Manchester United target is hotting up, Manchester City eye a January bid #manchester #bhive https://t.co/0YTAdusRvz',
#   None,
#   'Manchester, UK',
#   630,
#   438,
#   'Fri Nov 10 02:04:05 +0000 2017'),
#  ('ruby_gem',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester',
#   4865,
#   640,
#   'Fri Nov 10 00:35:28 +0000 2017'),
#  ('MelCityofLit',
#   'RT @UoMSALC: As @newwritingMCR turns 10 we look at the impact its had in shaping #Manchester #Cityofliterature: https://t.co/IJFJV1e31g #Uo…',
#   None,
#   'Melbourne Australia',
#   6132,
#   3468,
#   'Fri Nov 10 00:32:35 +0000 2017'),
#  ('a_lonelytree',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'The woods',
#   207,
#   66,
#   'Thu Nov 09 23:57:46 +0000 2017'),
#  ('McrDig',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, UK',
#   18624,
#   1149,
#   'Thu Nov 09 23:47:49 +0000 2017'),
#  ('Sportzz_me',
#   '#Characters #Manchester #Twitter #Utilise \nhttps://t.co/RUbAAeF8ZA',
#   None,
#   'World',
#   1100,
#   933,
#   'Thu Nov 09 23:38:26 +0000 2017'),
#  ('NCachetGaujard',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'England, United Kingdom',
#   547,
#   896,
#   'Thu Nov 09 23:17:27 +0000 2017'),
#  ('zoyastott',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester',
#   187,
#   231,
#   'Thu Nov 09 22:58:59 +0000 2017'),
#  ('TheJuiceAcademy',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, UK',
#   7685,
#   4026,
#   'Thu Nov 09 22:48:05 +0000 2017'),
#  ('TechNorthAdv',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'The North, UK ',
#   2988,
#   2479,
#   'Thu Nov 09 22:21:44 +0000 2017'),
#  ('naomitimperley',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester, UK',
#   31214,
#   23613,
#   'Thu Nov 09 22:21:24 +0000 2017'),
#  ('jamieofficer',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'London | Leeds | York',
#   2141,
#   1438,
#   'Thu Nov 09 21:52:16 +0000 2017'),
#  ('SandyLindsay',
#   "RT @RichesDaniel: 🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please RT 👍…",
#   None,
#   'Manchester',
#   14020,
#   12336,
#   'Thu Nov 09 21:51:09 +0000 2017'),
#  ('RichesDaniel',
#   "🔊Hey #Manchester Tech folks, @DWPDigital is hosting it's first hack to help reduce unemployment in the city. Please… https://t.co/rGmGV3BSlh",
#   None,
#   'London',
#   3017,
#   901,
#   'Thu Nov 09 21:48:57 +0000 2017'),
#  ('sleepyboyuk',
#   'Want some steamy fun in #Manchester tonight?\nThese #ManchesterGayEscorts can help: https://t.co/IsbwD9hDGC… https://t.co/g1LSicxBgj',
#   None,
#   'uk',
#   1645,
#   799,
#   'Thu Nov 09 21:25:05 +0000 2017'),
#  ('OHGSLangs',
#   'RT @WorldOfLang: #Manchester is a truly #multilingual city! Learn more with @mlmanchester on Friday! https://t.co/ZzYF25kNso #McrESRCFest #…',
#   None,
#   'Oldham, England',
#   223,
#   31,
#   'Thu Nov 09 21:05:04 +0000 2017'),
#  ('garybartanus',
#   'RT @Chri5rowell: City Arms #manchester https://t.co/Xec0kDFgfW',
#   None,
#   '',
#   1553,
#   3213,
#   'Thu Nov 09 20:53:10 +0000 2017'),
#  ('membranes1',
#   'Manchester-hatten - the big new skyline from my #manchester window- the city reaches for the… https://t.co/JWovV7pJ2q',
#   None,
#   '',
#   1708,
#   404,
#   'Thu Nov 09 20:38:29 +0000 2017'),
#  ('timnorton59',
#   'RT @spamuktour: A cracking write up following our press night on Tuesday in #Manchester! This really is one city we’re going miss, you’ve b…',
#   None,
#   'Hinckley, England',
#   51,
#   33,
#   'Thu Nov 09 20:21:54 +0000 2017'),
#  ('james_banting71',
#   'RT @davidg3907: @OLBG @toonmick70 @ibfm23 @UTR_83 #LEICESTER CITY v #Manchester City Preview and initial thoughts https://t.co/7kvIkS9V8L #…',
#   None,
#   '',
#   53,
#   87,
#   'Thu Nov 09 20:09:01 +0000 2017'),
#  ('_justmeedee',
#   'Catching up on last nights @DIYSOS the veterans whilst cooking tea .  Bloody love my city but I think these onions… https://t.co/ibyhVRPAyT',
#   None,
#   'Manchester ',
#   723,
#   494,
#   'Thu Nov 09 19:56:38 +0000 2017'),
#  ('mezomefans',
#   "Manchester City and Amazon link up for behind-the-scenes exclusive series following Pep Guardiola's side in their t… https://t.co/FUHspYQMHR",
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 19:52:11 +0000 2017'),
#  ('LynneLambourne',
#   'City life #manchester on the @thebestmelife #productivitymeetsmindfulness 2017 tour!! Great to… https://t.co/nX6Rd53piZ',
#   None,
#   'lovenellie.wordpress.com/',
#   2365,
#   2048,
#   'Thu Nov 09 19:49:18 +0000 2017'),
#  ('GoSochal',
#   "Ancient Manchester - 6 of the city's oldest buildings! https://t.co/6vjlUb2bM2   #history #lbloggers #WeBlogNorth… https://t.co/oOC9H0Pepa",
#   None,
#   'Manchester, England',
#   3654,
#   1229,
#   'Thu Nov 09 19:36:04 +0000 2017'),
#  ('uglybutler1',
#   'RT @spamuktour: A cracking write up following our press night on Tuesday in #Manchester! This really is one city we’re going miss, you’ve b…',
#   None,
#   '',
#   1905,
#   1856,
#   'Thu Nov 09 19:28:25 +0000 2017'),
#  ('MaddieMcfc',
#   '#mcfc fans please help me by tweeting, liking, sharing or even commenting anyone that may be able to help me in sur… https://t.co/V7lqpkcli8',
#   None,
#   'Manchester, England',
#   81,
#   433,
#   'Thu Nov 09 19:25:27 +0000 2017'),
#  ('craigybmc',
#   'At the Schloss for pre-drinks for our CB club night out #manchester #city #lifestyle #citylife… https://t.co/m7s65qYhd1',
#   {'coordinates': [53.4781818, -2.24799156], 'type': 'Point'},
#   'Manchester, England',
#   200,
#   716,
#   'Thu Nov 09 19:20:45 +0000 2017'),
#  ('greencoproperty',
#   "A rare chance to buy a property on one of #Manchester city centre's historic Anita Street. https://t.co/XdOEiEKtCk… https://t.co/Z3Psqom2zk",
#   None,
#   'Manchester, England',
#   258,
#   198,
#   'Thu Nov 09 18:56:03 +0000 2017'),
#  ('PensionPayroll',
#   'RT @SiBrownbill: Heading back to the great city of #Manchester from #CDMX . Actually looking forward to cool, fresh air...',
#   None,
#   'United Kingdom',
#   553,
#   1337,
#   'Thu Nov 09 18:49:47 +0000 2017'),
#  ('FreyaErica',
#   '#city #tower #sunset🌅 #Manchester https://t.co/TE9vu1xu8N',
#   None,
#   'Cheshire - United Kingdom',
#   398,
#   469,
#   'Thu Nov 09 18:38:00 +0000 2017'),
#  ('ttnesan',
#   "RT @RecEntrepreneur: #Manchester, the UK's fastest growing city is home to the newest Recruitment Entrepreneur office. We're on the hunt fo…",
#   None,
#   'London, Chennai and Bengaluru ',
#   874,
#   1945,
#   'Thu Nov 09 18:02:30 +0000 2017'),
#  ('MDAtoday',
#   'Looking forward to @BrabnersLLP in the City Winter Drinks tonight @BeAtOne_Mcr   #networking #youngprofessionals #Manchester',
#   None,
#   'Global',
#   1040,
#   714,
#   'Thu Nov 09 17:44:31 +0000 2017'),
#  ('jamescaan',
#   "RT @RecEntrepreneur: #Manchester, the UK's fastest growing city is home to the newest Recruitment Entrepreneur office. We're on the hunt fo…",
#   None,
#   'London',
#   175236,
#   1380,
#   'Thu Nov 09 17:38:13 +0000 2017'),
#  ('UTR_83',
#   'RT @davidg3907: @OLBG @toonmick70 @ibfm23 @UTR_83 #LEICESTER CITY v #Manchester City Preview and initial thoughts https://t.co/7kvIkS9V8L #…',
#   None,
#   'North West, England',
#   4201,
#   4989,
#   'Thu Nov 09 17:36:03 +0000 2017'),
#  ('cozmo0_4',
#   'City centre traffic is standstill. #Manchester',
#   None,
#   'Manchester England',
#   205,
#   349,
#   'Thu Nov 09 17:16:13 +0000 2017'),
#  ('Andybartonphoto',
#   'Over 75.000 people marched during the #PeoplesAssembly #demonstration against the Conservative Party Conference bei… https://t.co/l4Q3mF8lOh',
#   None,
#   'Manchester',
#   255,
#   271,
#   'Thu Nov 09 17:12:14 +0000 2017'),
#  ('mezomefans',
#   'Manchester City to be focal point of new Amazon Prime series #manchester #focal #point #amazon #prime #series… https://t.co/Y964U5gLAY',
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 17:04:16 +0000 2017'),
#  ('mezomefans',
#   'Manchester City to be focal point of new Amazon Prime series #manchester #focal #point #amazon #prime #series… https://t.co/1zZomfGJiv',
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 17:04:11 +0000 2017'),
#  ('mezomefans',
#   'Manchester City to be focal point of new Amazon Prime series #manchester #focal #point #amazon #prime #series… https://t.co/o3BHRSBlg3',
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 17:03:30 +0000 2017'),
#  ('toonmick70',
#   'RT @davidg3907: @OLBG @toonmick70 @ibfm23 @UTR_83 #LEICESTER CITY v #Manchester City Preview and initial thoughts https://t.co/7kvIkS9V8L #…',
#   None,
#   'Back Where I Belong',
#   2338,
#   1948,
#   'Thu Nov 09 16:53:51 +0000 2017'),
#  ('mezomefans',
#   'Chelsea have been overtaken by big-spending rivals Manchester City and United, insists Claudio Ranieri #chelsea… https://t.co/y4KVpLXPFb',
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 16:48:35 +0000 2017'),
#  ('mezomefans',
#   'Chelsea have been overtaken by big-spending rivals Manchester City and United, insists Claudio Ranieri #chelsea… https://t.co/5BCLgfs09r',
#   None,
#   '',
#   37791,
#   8,
#   'Thu Nov 09 16:48:21 +0000 2017'),
#  ('nbnibooks',
#   'RT @riewriting: Great to see @TheGEAcademy here in #Manchester #UNESCO City of Literature. https://t.co/s03NI3ZGUy',
#   None,
#   'Plymouth, UK',
#   2124,
#   4069,
#   'Thu Nov 09 16:41:45 +0000 2017'),
#  ('Ben_jones87',
#   'RT @Mullocks1996: Hot Lot 653 - one of the rarest #Football #Programmes for #Manchester #United - 1946/47 #Manchester Utd v #Stoke City No.…',
#   None,
#   'England, United Kingdom',
#   102,
#   204,
#   'Thu Nov 09 16:36:19 +0000 2017'),
#  ('RecEntrepreneur',
#   "#Manchester, the UK's fastest growing city is home to the newest Recruitment Entrepreneur office. We're on the hunt… https://t.co/YlmfQg8Dgk",
#   None,
#   'United Kingdom',
#   3199,
#   1408,
#   'Thu Nov 09 16:36:09 +0000 2017'),
#  ('ProjectResJobs',
# ...
#   None,
#   'Manchester, England',
#   40,
#   92,
#   'Sat Nov 04 09:32:36 +0000 2017'),
#  ('Southsidemag',
#   "RT @KEY103NEWS: It's beginning to look at lot like #Christmas...\nThousands expected in #Manchester city centre later as we switch the Chris…",
#   None,
#   'M22 and M23',
#   815,
#   1686,
#   'Sat Nov 04 09:30:25 +0000 2017'),
#  ('KEY103NEWS',
#   "It's beginning to look at lot like #Christmas...\nThousands expected in #Manchester city centre later as we switch t… https://t.co/48tAA9srxB",
#   None,
#   'Manchester',
#   28222,
#   1773,
#   'Sat Nov 04 09:28:29 +0000 2017'),
#  ('ILoveMCR',
#   'RT @CopThatCooks: #Manchester City Police’s PC Harry Knowles makes a call from the city’s first #police box in 1928.\n\n◾ Follow @HistoryCop…',
#   None,
#   'Manchester, England',
#   69651,
#   3100,
#   'Sat Nov 04 09:21:14 +0000 2017'),
#  ('friendsclarem',
#   'RT @CopThatCooks: #Manchester City Police’s PC Harry Knowles makes a call from the city’s first #police box in 1928.\n\n◾ Follow @HistoryCop…',
#   None,
#   'Clare',
#   600,
#   649,
#   'Sat Nov 04 09:17:14 +0000 2017'),
#  ('HistoryCop',
#   'RT @CopThatCooks: #Manchester City Police’s PC Harry Knowles makes a call from the city’s first #police box in 1928.\n\n◾ Follow @HistoryCop…',
#   None,
#   'Great Malvern',
#   1951,
#   1,
#   'Sat Nov 04 09:14:00 +0000 2017'),
#  ('CopThatCooks',
#   '#Manchester City Police’s PC Harry Knowles makes a call from the city’s first #police box in 1928.\n\n◾ Follow… https://t.co/e0WV8bKSUH',
#   None,
#   'Worcester, England',
#   8798,
#   6383,
#   'Sat Nov 04 09:13:37 +0000 2017'),
#  ('mezomefans',
#   'Manchester City onto something ‘special’ with Guardiola – Gundogan #manchester #something #special #guardiola…… https://t.co/H8qLGaXvoK',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 09:05:47 +0000 2017'),
#  ('mezomefans',
#   'Manchester City onto something ‘special’ with Guardiola – Gundogan #manchester #something #special #guardiola…… https://t.co/bZo4dJ3sen',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 09:05:20 +0000 2017'),
#  ('mezomefans',
#   'Manchester City onto something ‘special’ with Guardiola – Gundogan #manchester #something #special #guardiola…… https://t.co/go8xeMPegA',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 09:04:16 +0000 2017'),
#  ('mezomefans',
#   'Manchester City onto something ‘special’ with Guardiola – Gundogan #manchester #something #special #guardiola…… https://t.co/8I1NixeRSz',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 09:04:06 +0000 2017'),
#  ('mezomefans',
#   'Manchester City onto something ‘special’ with Guardiola – Gundogan #manchester #something #special #guardiola…… https://t.co/6oUilCwYre',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 09:03:07 +0000 2017'),
#  ('cottonopolisNQ',
#   'RT @KarenO1980: Thanks @cottonopolisNQ - the pleasure was all ours! Cheers to Friday, cheers to our fab city #Manchester 💛🙌🏻🐝 https://t.co/…',
#   None,
#   '16 Newton Street, Manchester',
#   5853,
#   2655,
#   'Sat Nov 04 08:53:13 +0000 2017'),
#  ('HighPeakHallam',
#   'RT @MMULibrary: A #Manchester #ThenAndNow from our Local Collection. London Road Fire Station, one of the best buildings in the City. https…',
#   None,
#   'Tintwistle, England',
#   628,
#   1041,
#   'Sat Nov 04 08:16:45 +0000 2017'),
#  ('mezomefans',
#   "Manchester City keen on Liverpool contract rebel Emre Can and 'will rival Juventus for his signature' #manchester…… https://t.co/UWiwhdz7YI",
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 08:05:15 +0000 2017'),
#  ('mmu_RAH',
#   'RT @gothicmmu: .A new chapter begins: #Manchester named Unesco City of Literature. @guardian https://t.co/kDICaffkfp',
#   None,
#   'Manchester Metropolitan Uni',
#   2676,
#   2045,
#   'Sat Nov 04 07:44:06 +0000 2017'),
#  ('patmotlakwane',
#   'Which city will the bragging write tomorrow? #London or #Manchester',
#   {'coordinates': [-25.46263, 27.83541], 'type': 'Point'},
#   'Letlhabile, Brits',
#   279,
#   544,
#   'Sat Nov 04 07:08:10 +0000 2017'),
#  ('Whiteeeeey',
#   'Off to a city I hold so much affection for today.....#Manchester ❤️❤️❤️',
#   None,
#   'On a hill with a video camera ',
#   3552,
#   3304,
#   'Sat Nov 04 06:51:38 +0000 2017'),
#  ('thedscprize',
#   'What makes #Manchester the #UNESCO city of #Literature?https://t.co/P3T2I6Jw4s',
#   None,
#   '',
#   1127,
#   862,
#   'Sat Nov 04 05:48:54 +0000 2017'),
#  ('DynamicFrize',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester,England',
#   5064,
#   3063,
#   'Sat Nov 04 05:42:12 +0000 2017'),
#  ('rosarusa',
#   'RT @eamonncanniffe: Two pictures of the same #Manchester street  - the ghost city around the #ConservativePartyConference and the street fu…',
#   None,
#   '',
#   569,
#   1188,
#   'Sat Nov 04 05:14:41 +0000 2017'),
#  ('Ageless_2u',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/mfLF0gFYCc',
#   None,
#   '',
#   2683,
#   1771,
#   'Sat Nov 04 04:59:36 +0000 2017'),
#  ('Ageless_2u',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   '',
#   2683,
#   1771,
#   'Sat Nov 04 04:50:28 +0000 2017'),
#  ('hmk0417',
#   'RT @londonkoreanist: Congrats #Manchester, now a UNESCO City of Lit! Are you as excited as I am for the incomparable HAN KANG on 15/11? htt…',
#   None,
#   'somewhere',
#   4033,
#   4490,
#   'Sat Nov 04 04:39:02 +0000 2017'),
#  ('myfoodfantasy69',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/mfLF0gFYCc',
#   None,
#   'Manchester, England',
#   3734,
#   2826,
#   'Sat Nov 04 04:35:40 +0000 2017'),
#  ('myfoodfantasy69',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester, England',
#   3734,
#   2826,
#   'Sat Nov 04 04:28:29 +0000 2017'),
#  ('JobsBall',
#   'UX DESIGN RESEARCHER Needed #Manchester  #City #UK #jobs  Apply Now at https://t.co/v7wsHtHDuB',
#   None,
#   '',
#   1569,
#   1962,
#   'Sat Nov 04 03:52:12 +0000 2017'),
#  ('myfoodfantasy69',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester, England',
#   3734,
#   2826,
#   'Sat Nov 04 02:11:39 +0000 2017'),
#  ('Frizemedia',
#   'RT @Charlesfrize: #Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester,England',
#   3810,
#   2093,
#   'Sat Nov 04 02:06:38 +0000 2017'),
#  ('Charlesfrize',
#   '#Manchester - City Guide Information #FrizeMedia #DigitalMarketing #Travel https://t.co/wpP22G3bhv via @Charlesfrize',
#   None,
#   'Manchester,England',
#   16008,
#   9780,
#   'Sat Nov 04 01:30:43 +0000 2017'),
#  ('DonMeeChoi',
#   'RT @londonkoreanist: Congrats #Manchester, now a UNESCO City of Lit! Are you as excited as I am for the incomparable HAN KANG on 15/11? htt…',
#   None,
#   '',
#   988,
#   833,
#   'Sat Nov 04 01:25:40 +0000 2017'),
#  ('SAVAZURNIC',
#   'RT @AerialVideoTV: And this is why we love #Manchester so much! #skyline #construction @SimpsonHaugh @Cloud23Bar @InnsideMCR @mcr_central @…',
#   None,
#   'Worldwide',
#   462,
#   454,
#   'Sat Nov 04 01:13:03 +0000 2017'),
#  ('becinmonton',
#   "RT @circlesquaremcr: Did you know #Manchester #OxfordRoad is an exciting part of the city's history? Find out more.  https://t.co/9WYfjmraY…",
#   None,
#   'Salford',
#   1244,
#   3727,
#   'Sat Nov 04 00:49:11 +0000 2017'),
#  ('mezomefans',
#   'Manchester City to give record goalscorer Sergio Aguero guard of honour before clash with Arsenal #manchester…… https://t.co/HSCwHJ2r3d',
#   None,
#   '',
#   37791,
#   8,
#   'Sat Nov 04 00:05:10 +0000 2017'),
#  ('KarenO1980',
#   'Thanks @cottonopolisNQ - the pleasure was all ours! Cheers to Friday, cheers to our fab city #Manchester 💛🙌🏻🐝 https://t.co/6gmzTLORf5',
#   None,
#   'Manchester, England',
#   562,
#   1143,
#   'Fri Nov 03 23:49:24 +0000 2017'),
#  ('zero1one7',
#   'Manchester City Fan... #manchester #fan #mancity #mancityfan https://t.co/Ve16osYD1l https://t.co/ATggZqtSoq',
#   None,
#   'London',
#   18,
#   80,
#   'Fri Nov 03 23:25:25 +0000 2017'),
#  ('MancheserVibes',
#   'Favourite thing about our city?? #manchester',
#   None,
#   'Manchester, England',
#   27,
#   225,
#   'Fri Nov 03 23:12:07 +0000 2017'),
#  ('JohnM_foto',
#   'Manchester central library arches #IRPhotographyPosse #fotografia #city #bnwphotography #bnw_city #bnw #manchester https://t.co/KBV5hUJXpD',
#   None,
#   'Lancashire',
#   8514,
#   7044,
#   'Fri Nov 03 23:00:29 +0000 2017'),
#  ('FemTherapy',
#   '#Manchester A great city with a great history. Be proud of your heritage!https://t.co/yPnuz8o5Zz https://t.co/LmX5sC6STB',
#   None,
#   'United Kingdom',
#   242,
#   87,
#   'Fri Nov 03 22:53:27 +0000 2017'),
#  ('Trentprice101',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'United Kingdom',
#   863,
#   1244,
#   'Fri Nov 03 22:45:55 +0000 2017'),
#  ('soccertee5',
#   'RT @soccertee5: https://t.co/nVDFxohjau out now #citizens #citizen #mcfc #city #Manchester',
#   None,
#   'United Kingdom',
#   4494,
#   4513,
#   'Fri Nov 03 22:25:50 +0000 2017'),
#  ('ryanpitts109',
#   'RT @DaisywBrown: Join us for a Christmas Charity Collection for @mencap_charity on Sun 17th Dec in #Manchester City Centre! Register: https…',
#   None,
#   'Pembury Kent',
#   187,
#   385,
#   'Fri Nov 03 22:13:51 +0000 2017'),
#  ('onedsaremylife',
#   'RT @LarryNewsItaly: ✿* • #Manchester | "Alcuni di voi sono fan dello United, altri del City, altri del Liverpool, ma possiamo essere gentil…',
#   None,
#   '-Larry-✨',
#   2399,
#   2738,
#   'Fri Nov 03 22:12:12 +0000 2017'),
#  ('MrKing_MEA',
#   'Tonight showed the amazing talent of the young people in Manchester, an absoutle assest to our city and nation. #youthbuzzawards #manchester',
#   None,
#   'Wythenshawe, Manchester UK',
#   220,
#   371,
#   'Fri Nov 03 22:10:45 +0000 2017'),
#  ('JohnRealSmith',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'A small island off Europe',
#   1782,
#   248,
#   'Fri Nov 03 21:53:05 +0000 2017'),
#  ('amzaritsky',
#   'RT @DaisywBrown: Join us for a Christmas Charity Collection for @mencap_charity on Sun 17th Dec in #Manchester City Centre! Register: https…',
#   None,
#   'London SW19',
#   554,
#   453,
#   'Fri Nov 03 21:39:14 +0000 2017'),
#  ('WessexInfidel',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'The Serpentine, Hyde Park',
#   316,
#   241,
#   'Fri Nov 03 21:38:01 +0000 2017'),
#  ('SerenaJB3',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   '',
#   4597,
#   5033,
#   'Fri Nov 03 21:37:34 +0000 2017'),
#  ('szilviade_',
#   'RT @AndrewPBrooks: More eerie places, all these in #Manchester\nCanal tunnels beneath the streets of the city &amp; up in the rafters of the Alb…',
#   None,
#   '',
#   1224,
#   437,
#   'Fri Nov 03 21:36:00 +0000 2017'),
#  ('buckleylad88',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'Buckley, Wales',
#   626,
#   770,
#   'Fri Nov 03 21:33:37 +0000 2017'),
#  ('andrewdavidcleg',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'Bradford',
#   408,
#   791,
#   'Fri Nov 03 21:29:41 +0000 2017'),
#  ('YorkCounty1993',
#   'RT @hostileholly5w: Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'Yorkshire and The Humber',
#   528,
#   524,
#   'Fri Nov 03 21:28:27 +0000 2017'),
#  ('hostileholly5w',
#   'Right wing absolutely own Manchester city centre tonight, Antifa? ha ha ha #5w #manchester',
#   None,
#   'Bermondsey',
#   5526,
#   5800,
#   'Fri Nov 03 21:28:14 +0000 2017'),
#  ('BLAENAUFFESTNOW',
#   'RT @AndrewPBrooks: More eerie places, all these in #Manchester\nCanal tunnels beneath the streets of the city &amp; up in the rafters of the Alb…',
#   None,
#   'Blaenau Ffestiniog,Wales.LL41',
#   1582,
#   1123,
#   'Fri Nov 03 21:26:56 +0000 2017'),
#  ('blackinana',
#   'RT @londonkoreanist: Congrats #Manchester, now a UNESCO City of Lit! Are you as excited as I am for the incomparable HAN KANG on 15/11? htt…',
#   None,
#   '',
#   16167,
#   557,
#   'Fri Nov 03 20:47:17 +0000 2017'),
#  ('mezomefans',
#   "Manchester City a 'big problem' for Premier League title hopefuls, acknowledges Conte #manchester #problem #premier… https://t.co/cOBsnMfLCw",
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 03 20:04:05 +0000 2017'),
#  ('mezomefans',
#   "Manchester City a 'big problem' for Premier League title hopefuls, acknowledges Conte #manchester #problem #premier… https://t.co/BIc7Yinrw2",
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 03 20:03:35 +0000 2017'),
#  ('mezomefans',
#   "Manchester City a 'big problem' for Premier League title hopefuls, acknowledges Conte #manchester #problem #premier… https://t.co/WXHi12YzAD",
#   None,
#   '',
#   37791,
#   8,
#   'Fri Nov 03 20:03:16 +0000 2017'),
#  ('_kabeer',
#   '#Alexis #Sanchez to #Manchester #City #ManchesterCity is happening in Jan! https://t.co/fxRDFwRUNd',
#   None,
#   'Hamburg, Germany',
#   422,
#   144,
#   'Fri Nov 03 19:10:19 +0000 2017'),
#  ('citylife__pics',
#   'RT @_this_is_reece: Buildings everywhere.😍\n\n#manchester #city #skyscraper #photography https://t.co/f370wwfkr9',
#   None,
#   '',
#   1544,
#   5002,
#   'Fri Nov 03 18:57:46 +0000 2017'),
#  ('ben_nuttall',
#   'RT @MMULibrary: A #Manchester #ThenAndNow from our Local Collection. London Road Fire Station, one of the best buildings in the City. https…',
#   None,
#   'Cambridge, UK',
#   7615,
#   596,
#   'Fri Nov 03 18:37:00 +0000 2017'),
#  ('canalstmancs',
#   'RT @MMULibrary: A #Manchester #ThenAndNow from our Local Collection. London Road Fire Station, one of the best buildings in the City. https…',
#   None,
#   'Manchester, England',
#   21085,
#   5758,
#   'Fri Nov 03 18:32:45 +0000 2017'),
#  ('mcrshield',
#   'RT @MMULibrary: A #Manchester #ThenAndNow from our Local Collection. London Road Fire Station, one of the best buildings in the City. https…',
#   None,
#   'Manchester, England',
#   2253,
#   1965,
#   'Fri Nov 03 18:32:18 +0000 2017'),
#  ('adriaramaral',
#   'RT @gothicmmu: .A new chapter begins: #Manchester named Unesco City of Literature. @guardian https://t.co/kDICaffkfp',
#   None,
#   'Porto Alegre, Brazil',
#   3376,
#   2819,
#   'Fri Nov 03 18:27:01 +0000 2017'),
#  ('LevyOldLibrary',
#   'RT @GoogleExpertUK: @tyrower @zophilpott @ManchesterLib @CodeClubSW @WomenInTechRT @TechNorthHQ @CathyConneff @AdaTheShow #Manchester and #…',
#   None,
#   'Manchester, England',
#   464,
#   711,
#   'Fri Nov 03 18:20:57 +0000 2017'),
#  ('acrim',
#   'I just got back to #Manchester &amp; the distant chants of “no means no!” Are echoing around the streets from a demonstration. I love this city.',
#   None,
#   'Manchester, UK',
#   2374,
#   3328,
#   'Fri Nov 03 18:15:13 +0000 2017'),
#  ('_this_is_reece',
#   'Buildings everywhere.😍\n\n#manchester #city #skyscraper #photography https://t.co/f370wwfkr9',
#   None,
#   'West Yorkshire (UK)  ',
#   8058,
#   6800,
#   'Fri Nov 03 18:12:14 +0000 2017'),
#  ('GoSochal',
#   "Ancient Manchester - 6 of the city's oldest buildings! https://t.co/2SurF6mAsz #history #lbloggers #WeBlogNorth… https://t.co/HGC59wgKSk",
#   None,
#   'Manchester, England',
#   3654,
#   1229,
#   'Fri Nov 03 18:01:52 +0000 2017'),
#  ('gavinwhite76',
#   'RT @ManCityCouncil: More interesting #Manchester facts are available in our State of the City report 2017. \nView them here: https://t.co/86…',
#   None,
#   'Withington, Manchester',
#   1239,
#   991,
#   'Fri Nov 03 18:00:57 +0000 2017'),
#  ('Po6baholic',
#   'Media City is lit #Manchester https://t.co/4wcNHDirUz',
#   None,
#   'Salford, Manchester. UK',
#   1374,
#   692,
#   'Fri Nov 03 17:45:54 +0000 2017'),
#  ('sueg501',
#   'RT @LevyOldLibrary: We ❤️ this: #Manchester named a UNESCO Creative City of Literature 🤓🥇📖✒️📚🖋️👍🤓\nhttps://t.co/jclffEuN8b',
#   None,
#   '',
#   59,
#   46,
#   'Fri Nov 03 17:43:00 +0000 2017')]

# %%
from __future__ import print_function
import tweepy
import json
import MySQLdb 
from dateutil import parser

WORDS = ['#bigdata', '#AI', '#datascience', '#machinelearning', '#ml', '#iot']

CONSUMER_KEY = "KEY"
CONSUMER_SECRET = "SECRET"
ACCESS_TOKEN = "TOKEN"
ACCESS_TOKEN_SECRET = "TOKEN_SECRET"

HOST = "YOUR_DATABASE_HOST"
USER = "YOUR_DATABASE_USER"
PASSWD = "YOUR_DATABASE_PASSWORD"
DATABASE = "YOUR_DATABASE"

# This function takes the 'created_at', 'text', 'screen_name' and 'tweet_id' and stores it
# into a MySQL database
def store_data(created_at, text, screen_name, tweet_id):
    db=MySQLdb.connect(host=HOST, user=USER, passwd=PASSWD, db=DATABASE, charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter (tweet_id, screen_name, created_at, text) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (tweet_id, screen_name, created_at, text))
    db.commit()
    cursor.close()
    db.close()
    return

class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 

    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the wanted data from the Tweet
            text = datajson['text']
            screen_name = datajson['user']['screen_name']
            tweet_id = datajson['id']
            created_at = parser.parse(datajson['created_at']) 

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            
            #insert the data into the MySQL database
            store_data(created_at, text, screen_name, tweet_id)
        
        except Exception as e:
            print(e)

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
